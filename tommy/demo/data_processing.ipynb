# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
import pandas as pd

# %%
data = pd.read_json('./datasets/reviews_Amazon_Instant_Video_5.json', lines=True)

# %%
data
# Out:
#            reviewerID        asin                    reviewerName   helpful  \
# 0      A11N155CW1UV02  B000H00VBQ                        AdrianaM    [0, 0]
# 1      A3BC8O2KCL29V2  B000H00VBQ                         Carol T    [0, 0]
# 2       A60D5HQFOTSOM  B000H00VBQ  Daniel Cooper "dancoopermedia"    [0, 1]
# 3      A1RJPIGRSNX4PW  B000H00VBQ                  J. Kaplan "JJ"    [0, 0]
# 4      A16XRPF40679KG  B000H00VBQ                   Michael Dobey    [1, 1]
# ...               ...         ...                             ...       ...
# 37121  A1ELO9LMSE1CQ7  B00LPWPMCS                           Mpr90    [0, 0]
# 37122   AGOEKVIJV9UX6  B00LPWPMCS                    Mr. Markster  [13, 15]
# 37123  A3I291BE0RNZCU  B00LPWPMCS             Rating My Best Pick    [0, 2]
# 37124  A1MNITZRYU71IO  B00LPWPMCS         Sherry "trying in ohio"    [1, 1]
# 37125  A1XMHK9HN5MW2H  B00LPWPMCS            Victoria J. Dennison    [3, 4]
#
# ...

# %%
data[0:len(data):100]
# Out:
#            reviewerID        asin                   reviewerName   helpful  \
# 0      A11N155CW1UV02  B000H00VBQ                       AdrianaM    [0, 0]
# 100     APL6O92MS25MJ  B000HZEHL6             H. Jeanne Rockwell    [0, 0]
# 200     AUOZZLT9ERJ6S  B000I9TWV6                   Lisa M Wiley    [0, 0]
# 300    A33LMH8SBNUA76  B000IJRK7O           Wolfgang "Film & TV"    [1, 3]
# 400    A1EMD1AUIURQVJ  B000J0Q1KO                         LHoose    [0, 0]
# ...               ...         ...                            ...       ...
# 36700  A3JZJIPXCY4LAQ  B00KF7NNTI                             RJ    [2, 2]
# 36800  A1MBUFIKA1GT6T  B00KPQ7TR6               PATRICIA COLBURN    [0, 0]
# 36900  A15C809ZYW2Z2G  B00KYZMSQ0                           MsEE  [25, 26]
# 37000   ACOI2LBXVDS9P  B00L86ZKAK  Ms. Annette Arnold "nucie 50"    [1, 2]
# 37100  A3OD04P0A831WB  B00LG0DKBO                      yongbing1    [1, 5]
#
#                                               reviewText  overall  \
# ...

# %%
data[0:len(data):100].to_csv('test.csv', encoding='utf-8', index=False)

# %%
temp = pd.read_csv('test.csv')

# %%
test = pd.DataFrame()
test['itemID'] = temp['asin'] 
test['rating'] = temp['overall'] 
test['userID'] = temp['reviewerID'] 
test['timestamp'] = temp['unixReviewTime']

# %%
test
# Out:
#          itemID  rating          userID   timestamp
# 0    B000H00VBQ       2  A11N155CW1UV02  1399075200
# 1    B000HZEHL6       4   APL6O92MS25MJ  1375574400
# 2    B000I9TWV6       5   AUOZZLT9ERJ6S  1395360000
# 3    B000IJRK7O       4  A33LMH8SBNUA76  1188777600
# 4    B000J0Q1KO       5  A1EMD1AUIURQVJ  1379203200
# ..          ...     ...             ...         ...
# 367  B00KF7NNTI       4  A3JZJIPXCY4LAQ  1402963200
# 368  B00KPQ7TR6       5  A1MBUFIKA1GT6T  1405814400
# 369  B00KYZMSQ0       4  A15C809ZYW2Z2G  1403654400
# 370  B00L86ZKAK       5   ACOI2LBXVDS9P  1405641600
# 371  B00LG0DKBO       3  A3OD04P0A831WB  1405209600
#
# [372 rows x 4 columns]

# %%
test.to_csv('testForInput.csv', encoding='utf-8', index=False)
